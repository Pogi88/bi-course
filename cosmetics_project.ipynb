# %%
import pandas as pd

# %%
df = pd.read_csv("cosmetics.csv")

# %%
df
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# ...

# %%
df.columns
# Out:
# Index(['Label', 'Brand', 'Name', 'Price', 'Rank', 'Ingredients', 'Combination',
#        'Dry', 'Normal', 'Oily', 'Sensitive'],
#       dtype='object')

# %%
df2 = df.drop('Ingredients', axis=1)

# %%
df2
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# ...

# %%
df2.T
# Out:
#                         0                         1     \
# Label            Moisturizer               Moisturizer
# Brand                 LA MER                     SK-II
# Name         Crème de la Mer  Facial Treatment Essence
# Price                    175                       179
# Rank                     4.1                       4.1
# Combination                1                         1
# Dry                        1                         1
# Normal                     1                         1
# Oily                       1                         1
# Sensitive                  1                         1
#
#                                    2                            3     \
# Label                       Moisturizer                  Moisturizer
# Brand                    DRUNK ELEPHANT                       LA MER
# Name         Protini™ Polypeptide Cream  The Moisturizing Soft Cream
# Price                                68                          175
# ...

# %%
df2.T.to_dict()
# Out:
# {0: {'Label': 'Moisturizer',
#   'Brand': 'LA MER',
#   'Name': 'Crème de la Mer',
#   'Price': 175,
#   'Rank': 4.1,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 1},
#  1: {'Label': 'Moisturizer',
#   'Brand': 'SK-II',
#   'Name': 'Facial Treatment Essence',
#   'Price': 179,
#   'Rank': 4.1,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 1},
#  2: {'Label': 'Moisturizer',
#   'Brand': 'DRUNK ELEPHANT',
#   'Name': 'Protini™ Polypeptide Cream',
#   'Price': 68,
#   'Rank': 4.4,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 0},
#  3: {'Label': 'Moisturizer',
#   'Brand': 'LA MER',
#   'Name': 'The Moisturizing Soft Cream',
#   'Price': 175,
#   'Rank': 3.8,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 1},
#  4: {'Label': 'Moisturizer',
#   'Brand': 'IT COSMETICS',
#   'Name': 'Your Skin But Better™ CC+™ Cream with SPF 50+',
# ...

# %%
df2.T.to_dict().values()
# Out:
# dict_values([{'Label': 'Moisturizer', 'Brand': 'LA MER', 'Name': 'Crème de la Mer', 'Price': 175, 'Rank': 4.1, 'Combination': 1, 'Dry': 1, 'Normal': 1, 'Oily': 1, 'Sensitive': 1}, {'Label': 'Moisturizer', 'Brand': 'SK-II', 'Name': 'Facial Treatment Essence', 'Price': 179, 'Rank': 4.1, 'Combination': 1, 'Dry': 1, 'Normal': 1, 'Oily': 1, 'Sensitive': 1}, {'Label': 'Moisturizer', 'Brand': 'DRUNK ELEPHANT', 'Name': 'Protini™ Polypeptide Cream', 'Price': 68, 'Rank': 4.4, 'Combination': 1, 'Dry': 1, 'Normal': 1, 'Oily': 1, 'Sensitive': 0}, {'Label': 'Moisturizer', 'Brand': 'LA MER', 'Name': 'The Moisturizing Soft Cream', 'Price': 175, 'Rank': 3.8, 'Combination': 1, 'Dry': 1, 'Normal': 1, 'Oily': 1, 'Sensitive': 1}, {'Label': 'Moisturizer', 'Brand': 'IT COSMETICS', 'Name': 'Your Skin But Better™ CC+™ Cream with SPF 50+', 'Price': 38, 'Rank': 4.1, 'Combination': 1, 'Dry': 1, 'Normal': 1, 'Oily': 1, 'Sensitive': 1}, {'Label': 'Moisturizer', 'Brand': 'TATCHA', 'Name': 'The Water Cream', 'Price
# ...

# %%
list(df2.T.to_dict().values())
# Out:
# [{'Label': 'Moisturizer',
#   'Brand': 'LA MER',
#   'Name': 'Crème de la Mer',
#   'Price': 175,
#   'Rank': 4.1,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 1},
#  {'Label': 'Moisturizer',
#   'Brand': 'SK-II',
#   'Name': 'Facial Treatment Essence',
#   'Price': 179,
#   'Rank': 4.1,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 1},
#  {'Label': 'Moisturizer',
#   'Brand': 'DRUNK ELEPHANT',
#   'Name': 'Protini™ Polypeptide Cream',
#   'Price': 68,
#   'Rank': 4.4,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 0},
#  {'Label': 'Moisturizer',
#   'Brand': 'LA MER',
#   'Name': 'The Moisturizing Soft Cream',
#   'Price': 175,
#   'Rank': 3.8,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 1},
#  {'Label': 'Moisturizer',
#   'Brand': 'IT COSMETICS',
#   'Name': 'Your Skin But Better™ CC+™ Cream with SPF 50+',
#   'Price': 38,
# ...

# %%
list(df2.head(3).T.to_dict().values())
# Out:
# [{'Label': 'Moisturizer',
#   'Brand': 'LA MER',
#   'Name': 'Crème de la Mer',
#   'Price': 175,
#   'Rank': 4.1,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 1},
#  {'Label': 'Moisturizer',
#   'Brand': 'SK-II',
#   'Name': 'Facial Treatment Essence',
#   'Price': 179,
#   'Rank': 4.1,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 1},
#  {'Label': 'Moisturizer',
#   'Brand': 'DRUNK ELEPHANT',
#   'Name': 'Protini™ Polypeptide Cream',
#   'Price': 68,
#   'Rank': 4.4,
#   'Combination': 1,
#   'Dry': 1,
#   'Normal': 1,
#   'Oily': 1,
#   'Sensitive': 0}]

# %%
import json

# %%
json_string = json.dumps(list(df2.T.to_dict().values()))

# %%
# alt + shift + f formazas vega liteban

# %%
open('cosmetics_data.json','w').write(json_string)
# Out:
# 282841
